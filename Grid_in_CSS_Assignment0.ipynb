# %% [markdown]
# Task 1:
#
#
# Problem Statement
#
# Create an image gallery using a CSS grid.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Image Gallery</title>
    <style>
        body {
            margin: 0;
            padding: 20px;
            background-color: bisque;
        }
        .gallery {
            display: grid;
            grid-template-columns: repeat(3,1fr);
            grid: gap 10px;
            max-width: 1000px;
            margin: auto;
        }
        .gallery img {
            width: 100%;
            height: 100%;
            object-fit: cover;
            border-radius: 6px;

        }
        .gallery img:first-child {
            grid-column: span 2;
        }














    </style>





</head>
<body>

    <div class="gallery">
        <img

           src="https://thumbs.dreamstime.com/b/chemistry-laboratory-woman-pipettes-test-tubes-chemistry-laboratory-woman-pipettes-114782620.jpg"
              />
          <img

             src="https://www.angiplast.com/wp-content/uploads/2022/03/Syringe.jpg"
                />
                <img

                   src="https://sellet.in/wp-content/uploads/2024/06/Photoroom-20240608_171403_45-1-600x450.jpg"
                    />
                <img

                   src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSUeds3MOfoj0iyQYTnxh-so8jRxa3Ax1Y0gg&s"
                        />
                <img

                    src="https://t4.ftcdn.net/jpg/00/05/86/25/360_F_5862533_wQ6IJRVm6vLtub3aqirHc0AsUK3EfloS.jpg"
                         />
                 <img

                      src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSFsjY0GgoCawX6w9G3WehEMcBWUs7t8bFasw&s"
                           />










    </div>


</body>
</html>

# %% [markdown]
# Task 2:
#
#
# Problem Statement
#
# Write code to arrange containers with texts A, B, C, and D as shown in the below image.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>container Arrangement</title>
    <style>
    .container {
        display: flex;
        flex-direction: row;
        justify-content: space-around;
        align-items: center;
        width: 300px;
        height: 100px;
        border: 1px solid black;

    }
    .item {
        width: 50px;
        height: 50px;
        background-color: bisque;
        text-align: center;
        line-height: 50px;
        font-size: 20px;
    }
    .item A {
        width: 100px;
        height: 100px;
    }
    </style>

</head>
<body>
    <div class="container">
        <div class="item">A</div>
        <div class="item">B</div>
        <div class="item">C</div>
        <div class="item">D</div>
    </div>
</body>
</html>

# %% [markdown]
# Task 3:
#
#
# Problem Statement
#
# Explain the use of grid-auto-row and grid-auto-column using code examples.
# - grid-auto-rows
# The grid-auto-rows property defines the size of implicitly created grid rows. It's useful when the number of rows in a grid is not explicitly defined, or when items are placed outside of the explicitly defined rows.
# <div class="grid-container">
#   <div class="item">1</div>
#   <div class="item">2</div>
#   <div class="item">3</div>
#   <div class="item">4</div>
#   <div class="item">5</div>
#   <div class="item">6</div>
#   <div class="item">7</div>
# </div>
# Code
#
# .grid-container {
#   display: grid;
#   grid-template-columns: repeat(3, 1fr); /* Three columns */
#   grid-auto-rows: 100px; /* Implicit rows will be 100px high */
#   gap: 10px;
# }
#
# .item {
#   background-color: lightblue;
#   border: 1px solid black;
#   padding: 20px;
#   text-align: center;
# }
# grid-auto-columns
# The grid-auto-columns property defines the size of implicitly created grid columns. It's useful when the number of columns is not explicitly defined, or when items are placed outside of the explicitly defined columns.
# Code
#
# <div class="grid-container">
#   <div class="item">1</div>
#   <div class="item">2</div>
#   <div class="item">3</div>
#   <div class="item">4</div>
#   <div class="item">5</div>
#   <div class.item">6</div>
# </div>
# Code
#
# .grid-container {
#   display: grid;
#   grid-template-rows: repeat(2, 1fr); /* Two rows */
#   grid-auto-columns: 150px; /* Implicit columns will be 150px wide */
#   gap: 10px;
# }
#
# .item {
#   background-color: lightgreen;
#   border: 1px solid black;
#   padding: 20px;
#   text-align: center;
# }

# %% [markdown]
# Task 4:
#
#
# Problem Statement
#
# Write CSS to show numbers as shown in the figure, without altering the below html code.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>container Arrangement</title>
    <style>
    .container {
        display: grid;
        grid-template-columns: repeat(6,100px);
        padding: 20px;



        width: 600px;
        height: 150px;
        border: 1px solid black;

    }
    .box {
        width: 80px;
        height: 50px;
        background-color: beige;
        text-align: center;
        order: 2;
        border: 1px solid;
        border-radius: 5px;
        gap: 1px;
        font-size: 20px;

    }
.box1 {
    order: 4;
    background-color: black;
    color: white;
}
.box3 {
    order: 1;
    background-color: black;
    color: white;
}
.box2 {
    order:5;
    background-color: darkgray;
}
.box4 {
    background-color: darkgray;
}
.box5 {
    background-color: black;
    color: white;
}
.box6 {
    background-color: darkgray;
}
.box7 {
    background-color: black;
    color: white;
}
.box8 {
    background-color: darkgray;
    color: black;
}




    </style>

</head>
<body>
    <div class="container">
        <div class="box box1">1</div>
        <div class="box box2">2</div>
        <div class="box box3">3</div>
        <div class="box box4">4</div>
        <div class="box box5">5</div>
        <div class="box box6">6</div>
        <div class="box box7">7</div>
        <div class="box box8">8</div>
    </div>
</body>
</html>

# %% [markdown]
# Task 5:
#
#
# Problem Statement
#
# Explain the difference between justify-items and justify-self using code examples.
#  -   justify-items- controls the default horizontal alignment of all grid items within a grid container.
# It's set on the grid container element.
# Possible values include start, end, center, stretch (default), etc.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>document</title>
    <style>
    .grid-container {
        display: grid;
        grid-template-columns: repeat(3, 1fr);
        background-color: lightblue;
        height: 200px;

        justify-items: center;
    }
    .item {
        background-color: lightgreen;
        padding:10px;
        border: 1px solid black;



    }
    </style>
    </head>
    <body>
    <div class="grid-container">
        <div class="item">1</div>
        <div class="item">2</div>
        <div class="item">3</div>
        </div>
        </body>
        </html>

# %% [markdown]
# justify-self - is used to override the justify-items value for a specific grid item.
# It's set on the individual grid item element.
# It can be used to align an item differently than the rest of the grid items.
# Possible values are the same as justify-items.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>container Arrangement</title>
    <style>
    .grid-container {
        display:grid;
        grid-template-columns:repeat(3,100px);
        justify-items:start;
        background-color:lightgray;
        height:200px;
    }
    .item {
        background-color:lightblue;
        border:1px solid black;
        padding:10px;
        justify-self:end;
    }
    </style>
    </head>
    <body>
    <div class="grid-container">
    <div class="item">Item1</div>
    <div class="item">item2</div>
    <div class="item">item3</div>
    </div>
    </body>
    </html>
